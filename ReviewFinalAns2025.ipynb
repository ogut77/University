# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Course=pd.read_excel("https://github.com/ogut77/University/blob/main/Course.xlsx?raw=true")
Faculty=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty.xlsx?raw=true")
Student=pd.read_excel("https://github.com/ogut77/University/blob/main/Student.xlsx?raw=true")
Enrollment=pd.read_excel("https://github.com/ogut77/University/blob/main/Enrollment.xlsx?raw=true")
Offering=pd.read_excel("https://github.com/ogut77/University/blob/main/Offering.xlsx?raw=true")
Faculty_1=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty_1.xlsx?raw=true")
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.44)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=9d3d71426b003b71b06e9dc0f8f82b12261fe4e3426105579b797af5bf87b4c0
#   Stored in directory: /root/.cache/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
#Q1-List all student info. If student is faculty,list faculty information aswell

txt='''
Select *
FRom Student left join Faculty on Student.StdNo=Faculty.FacNo

'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#           StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1   124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 2   234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 3   345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 4   456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 5   567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 6   678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 7   789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 8   876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 9   890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 10  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#    StdMajor StdClass  StdGPA        FacNo FacFirstName FacLastName  FacCity  \
# 0        IS       FR     3.0         None         None        None     None
# 1       FIN       JR     2.7         None         None        None     None
# 2      ACCT       JR     3.5         None         None        None     None
# 3        IS       SR     2.8         None         None        None     None
# 4       FIN       SR     3.2         None         None        None     None
# 5        IS       JR     3.6         None         None        None     None
# 6      ACCT       SO     3.3         None         None        None     None
# 7       FIN       JR     2.5         None         None        None     None
# 8        IS       SR     4.0  876-54-3210   CRISTOPHER       COLAN  SEATTLE
# 9        IS       SR     2.2         None         None        None     None
# 10       IS       SO     3.8         None         None        None     None
#
#    FacState FacDept FacRank  FacSalary FacSupervisor  \
# 0      None    None    None        NaN          None
# 1      None    None    None        NaN          None
# 2      None    None    None        NaN          None
# 3      None    None    None        NaN          None
# 4      None    None    None        NaN          None
# 5      None    None    None        NaN          None
# 6      None    None    None        NaN          None
# 7      None    None    None        NaN          None
# 8        WA      MS    ASST    40000.0   654-32-1098
# 9      None    None    None        NaN          None
# 10     None    None    None        NaN          None
#
#                    FacHireDate  FacZipCode
# 0                         None        None
# 1                         None        None
# 2                         None        None
# 3                         None        None
# 4                         None        None
# 5                         None        None
# 6                         None        None
# 7                         None        None
# 8   2008-03-01 00:00:00.000000  98114-1332
# 9                         None        None
# 10                        None        None

# %%
#Q1a-List all student information who are  faculty as well

txt='''
Select *
FRom Student inner join Faculty on Student.StdNo=Faculty.FacNo
'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
#
#   StdMajor StdClass  StdGPA        FacNo FacFirstName FacLastName  FacCity  \
# 0       IS       SR     4.0  876-54-3210   CRISTOPHER       COLAN  SEATTLE
#
#   FacState FacDept FacRank  FacSalary FacSupervisor  \
# 0       WA      MS    ASST      40000   654-32-1098
#
#                   FacHireDate  FacZipCode
# 0  2008-03-01 00:00:00.000000  98114-1332

# %%
#Q1a-List all student information who are not   faculty

txt='''
Select Student.*
FRom Student left join Faculty on Student.StdNo=Faculty.FacNo
where Faculty.FacNo is null

'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1  124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 2  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 3  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 4  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 5  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 6  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 7  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 8  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 9  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0       IS       FR     3.0
# 1      FIN       JR     2.7
# 2     ACCT       JR     3.5
# 3       IS       SR     2.8
# 4      FIN       SR     3.2
# 5       IS       JR     3.6
# 6     ACCT       SO     3.3
# 7      FIN       JR     2.5
# 8       IS       SR     2.2
# 9       IS       SO     3.8

# %%
#Q1b-List all faculty information for people who are both faculty and student

txt='''



'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA      MS    ASST
#
#    FacSalary        StdNo StdFirstName StdLastName  StdCity StdState  \
# 0      40000  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA
#
#        StdZip StdMajor StdClass  StdGPA
# 0  98114-1332       IS       SR     4.0

# %%
#Q1b-List student information  who are not faculty

txt='''


'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1  124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 2  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 3  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 4  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 5  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 6  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 7  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 8  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 9  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0       IS       FR     3.0
# 1      FIN       JR     2.7
# 2     ACCT       JR     3.5
# 3       IS       SR     2.8
# 4      FIN       SR     3.2
# 5       IS       JR     3.6
# 6     ACCT       SO     3.3
# 7      FIN       JR     2.5
# 8       IS       SR     2.2
# 9       IS       SO     3.8

# %%
#Subquery Version
#Q1b-List student information  who are not faculty

txt='''
Select *
From Student
Where StdNo not in
(Select FacNo
From Faculty)

'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1  124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 2  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 3  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 4  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 5  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 6  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 7  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 8  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 9  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0       IS       FR     3.0
# 1      FIN       JR     2.7
# 2     ACCT       JR     3.5
# 3       IS       SR     2.8
# 4      FIN       SR     3.2
# 5       IS       JR     3.6
# 6     ACCT       SO     3.3
# 7      FIN       JR     2.5
# 8       IS       SR     2.2
# 9       IS       SO     3.8

# %%
#Q2- If faculty has supervisor ,list supervisor's name and salary
#in addition to all faculty
txt='''
Select f1.*, f2.FacFirstName, f2.FacLastName,f2.FacSalary
From Faculty f1 left join Faculty f2 on f1.FacSupervisor=f2.FacNo

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#          FacNo FacFirstName FacLastName   FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE   SEATTLE       WA      MS    ASST
# 1  543-21-0987     VICTORIA    EMMANUEL   BOTHELL       WA      MS    PROF
# 2  654-32-1098      LEONARD       FIBON   SEATTLE       WA      MS    ASSC
# 3  765-43-2109        NICKI       MACON  BELLEVUE       WA     FIN    PROF
# 4  876-54-3210   CRISTOPHER       COLAN   SEATTLE       WA      MS    ASST
# 5  987-65-4321        JULIA       MILLS   SEATTLE       WA     FIN    ASSC
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode  \
# 0      35000   654-32-1098  2004-04-10 00:00:00.000000  98111-9921
# 1     120000          None  2005-04-15 00:00:00.000000  98011-2242
# 2      70000   543-21-0987  2003-05-01 00:00:00.000000  98121-0094
# 3      65000          None  2006-04-11 00:00:00.000000  98015-9945
# 4      40000   654-32-1098  2008-03-01 00:00:00.000000  98114-1332
# 5      75000   765-43-2109  2009-03-15 00:00:00.000000  98114-9954
#
#   FacFirstName FacLastName  FacSalary
# 0      LEONARD       FIBON    70000.0
# 1         None        None        NaN
# 2     VICTORIA    EMMANUEL   120000.0
# 3         None        None        NaN
# 4      LEONARD       FIBON    70000.0
# 5        NICKI       MACON    65000.0

# %%
#Q3-List all courses who are not offered
#Hint Use left Join and look for one of column in Offering Table whose value is null.
txt='''
Select *
From Course left join Offering on Course.CourseNo=Offering.CourseNo
Where Offering.CourseNo is null
'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#   CourseNo                       CrsDesc  CrsUnits OfferNo CourseNo OffTerm  \
# 0    IS470  BUSINESS DATA COMMUNICATIONS         4    None     None    None
#
#   OffYear OffLocation OffTime FacNo OffDays
# 0    None        None    None  None    None

# %%
#Q3-List all courses who are not offered
#Hint Use left Join and look for one of column in Offering Table whose value is null.
txt='''
Select *
From Course
Where CourseNo NOT IN
(Select CourseNo
From Offering)
'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#   CourseNo                       CrsDesc  CrsUnits
# 0    IS470  BUSINESS DATA COMMUNICATIONS         4

# %%
#Q4-List all offerings and the faculty assigned to teach them .
#Also include courses without a faculty assigned to them and Course Name as well
#Hint:Use Join for 3 tables. Search internet how to do that
txt='''
Select Offering.*, Course.CrsDesc, Faculty.FacFirstName, Faculty.FacLastName
From Offering inner join Course on Offering.CourseNo=Course.CourseNo
left join Faculty on Offering.FacNo=Faculty.FacNo

'''
Q4 =  psql.sqldf(txt)
Q4
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      1111    IS320  SUMMER     2017      BLM302  10:30:00.000000
# 1      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 2      2222    IS460  SUMMER     2016      BLM412  13:30:00.000000
# 3      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 4      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 5      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 6      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 7      5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 8      5679    IS480  SPRING     2017      BLM412  15:30:00.000000
# 9      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 10     7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 11     8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 12     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
#
#           FacNo OffDays                               CrsDesc FacFirstName  \
# 0          None      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING         None
# 1   098-76-5432      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 2          None     TTH                      SYSTEMS ANALYSIS         None
# 3   098-76-5432      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 4   098-76-5432     TTH  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 5   543-21-0987     TTH  FUNDAMENTALS OF BUSINESS PROGRAMMING     VICTORIA
# 6   765-43-2109      MW               FUNDAMENTALS OF FINANCE        NICKI
# 7   987-65-4321      MW   FUNDAMENTALS OF DATABASE MANAGEMENT        JULIA
# 8   876-54-3210     TTH   FUNDAMENTALS OF DATABASE MANAGEMENT   CRISTOPHER
# 9   987-65-4321     TTH             PRINCIPLES OF INVESTMENTS        JULIA
# 10  765-43-2109      MW                     CORPORATE FINANCE        NICKI
# 11  654-32-1098      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 12  654-32-1098     TTH                      SYSTEMS ANALYSIS      LEONARD
#
#    FacLastName
# 0         None
# 1        VINCE
# 2         None
# 3        VINCE
# 4        VINCE
# 5     EMMANUEL
# 6        MACON
# 7        MILLS
# 8        COLAN
# 9        MILLS
# 10       MACON
# 11       FIBON
# 12       FIBON

# %%
#Q4-List all offerings and the faculty assigned to teach them .
#Also include courses without a faculty assigned to them and Course Name as well
#Hint:Use Join for 3 tables. Search internet how to do that
txt='''
Select Offering.*, Course.CrsDesc, Faculty.FacFirstName, Faculty.FacLastName
From Course inner join Offering on Offering.CourseNo=Course.CourseNo
left join Faculty on Offering.FacNo=Faculty.FacNo

'''
Q4 =  psql.sqldf(txt)
Q4
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 1      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 2      7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 3      1111    IS320  SUMMER     2017      BLM302  10:30:00.000000
# 4      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 5      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 6      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 7      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 8      8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 9      2222    IS460  SUMMER     2016      BLM412  13:30:00.000000
# 10     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
# 11     5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 12     5679    IS480  SPRING     2017      BLM412  15:30:00.000000
#
#           FacNo OffDays                               CrsDesc FacFirstName  \
# 0   765-43-2109      MW               FUNDAMENTALS OF FINANCE        NICKI
# 1   987-65-4321     TTH             PRINCIPLES OF INVESTMENTS        JULIA
# 2   765-43-2109      MW                     CORPORATE FINANCE        NICKI
# 3          None      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING         None
# 4   098-76-5432      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 5   098-76-5432      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 6   098-76-5432     TTH  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 7   543-21-0987     TTH  FUNDAMENTALS OF BUSINESS PROGRAMMING     VICTORIA
# 8   654-32-1098      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING      LEONARD
# 9          None     TTH                      SYSTEMS ANALYSIS         None
# 10  654-32-1098     TTH                      SYSTEMS ANALYSIS      LEONARD
# 11  987-65-4321      MW   FUNDAMENTALS OF DATABASE MANAGEMENT        JULIA
# 12  876-54-3210     TTH   FUNDAMENTALS OF DATABASE MANAGEMENT   CRISTOPHER
#
#    FacLastName
# 0        MACON
# 1        MILLS
# 2        MACON
# 3         None
# 4        VINCE
# 5        VINCE
# 6        VINCE
# 7     EMMANUEL
# 8        FIBON
# 9         None
# 10       FIBON
# 11       MILLS
# 12       COLAN

# %%
#Q4-List courses offfered but not taken any students.
txt='''
Select OfferNo
From Offering
Where OfferNo NOT IN
(Select OfferNo
From Enrollment)
'''
Q4 =  psql.sqldf(txt)
Q4

# %%
#Q5-List  Student LastName and FirstName of the Student with StdGPA greater than average GPA
#Use nested query by calculating average GPA first.
txt='''
Select *
From Student
Where StdGPA >
(Select AVG(StdGPA)
From Student)
'''
Q5 =  psql.sqldf(txt)
Q5
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 1  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 2  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 3  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 4  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 5  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0     ACCT       JR     3.5
# 1      FIN       SR     3.2
# 2       IS       JR     3.6
# 3     ACCT       SO     3.3
# 4       IS       SR     4.0
# 5       IS       SO     3.8

# %%
#Q5-List  Student LastName and FirstName of the Student with StdGPA greater than average GPA
#Put Averge GPA intoas a column to the Query
#Use nested query by calculating average GPA first.
txt='''
Select *,(Select AVG(StdGPA)
From Student) AS AvgGPA
From Student
Where StdGPA >
(Select AVG(StdGPA)
From Student)
'''
Q5 =  psql.sqldf(txt)
Q5
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 1  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 2  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 3  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 4  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 5  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA    AvgGPA
# 0     ACCT       JR     3.5  3.145455
# 1      FIN       SR     3.2  3.145455
# 2       IS       JR     3.6  3.145455
# 3     ACCT       SO     3.3  3.145455
# 4       IS       SR     4.0  3.145455
# 5       IS       SO     3.8  3.145455

# %%
#Q6-List Faculty information with a maximium and minimum salary
#Hint use nested query to calculate max and min in the form like- where FacSalary=(...) or FacSalary=(....)
txt='''
Select *
From Faculty
Where FacSalary=(Select MAX(FacSalary)
From Faculty)
OR FacSalary=(Select MIN(FacSalary)
From Faculty)
'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE  SEATTLE       WA      MS    ASST
# 1  543-21-0987     VICTORIA    EMMANUEL  BOTHELL       WA      MS    PROF
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0      35000   654-32-1098  2004-04-10 00:00:00.000000  98111-9921
# 1     120000          None  2005-04-15 00:00:00.000000  98011-2242

# %%
#Q7-List Faculty information having salary greater than average salary  and
#people with minimum salary
#Hint use nested query to calculate max and min in the form like- where FacSalary=(...) or FacSalary=(....)
txt='''
Select *
From Faculty
Where FacSalary>(Select AVG(FacSalary)
From Faculty)
OR FacSalary=(Select MIN(FacSalary)
From Faculty)
'''
Q7 =  psql.sqldf(txt)
Q7
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE  SEATTLE       WA      MS    ASST
# 1  543-21-0987     VICTORIA    EMMANUEL  BOTHELL       WA      MS    PROF
# 2  654-32-1098      LEONARD       FIBON  SEATTLE       WA      MS    ASSC
# 3  987-65-4321        JULIA       MILLS  SEATTLE       WA     FIN    ASSC
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0      35000   654-32-1098  2004-04-10 00:00:00.000000  98111-9921
# 1     120000          None  2005-04-15 00:00:00.000000  98011-2242
# 2      70000   543-21-0987  2003-05-01 00:00:00.000000  98121-0094
# 3      75000   765-43-2109  2009-03-15 00:00:00.000000  98114-9954

# %%
#Q8- List faculty name and lastname who are Supervisor of other faculty.
#Use nested faculty by finding Facno of FacSupervisor where FacSupervisor is not null
txt='''
Select *
From Faculty
Where FAcNo IN(
Select FacSupervisor
From Faculty
Where FacSupervisor is not null)
'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#          FacNo FacFirstName FacLastName   FacCity FacState FacDept FacRank  \
# 0  543-21-0987     VICTORIA    EMMANUEL   BOTHELL       WA      MS    PROF
# 1  654-32-1098      LEONARD       FIBON   SEATTLE       WA      MS    ASSC
# 2  765-43-2109        NICKI       MACON  BELLEVUE       WA     FIN    PROF
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0     120000          None  2005-04-15 00:00:00.000000  98011-2242
# 1      70000   543-21-0987  2003-05-01 00:00:00.000000  98121-0094
# 2      65000          None  2006-04-11 00:00:00.000000  98015-9945

# %%
#Q9- List faculty name and lastname who has  Supervisor
txt='''
Select *
FRom Faculty
Where FacSupervisor is not null
'''
Q9 =  psql.sqldf(txt)
Q9

# %%
#Q10- List faculty name and lastname who has not Supervisor
txt='''
Select *
FRom Faculty
Where FacSupervisor is null

'''
Q10 =  psql.sqldf(txt)
Q10
# Out:
#          FacNo FacFirstName FacLastName   FacCity FacState FacDept FacRank  \
# 0  543-21-0987     VICTORIA    EMMANUEL   BOTHELL       WA      MS    PROF
# 1  765-43-2109        NICKI       MACON  BELLEVUE       WA     FIN    PROF
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0     120000          None  2005-04-15 00:00:00.000000  98011-2242
# 1      65000          None  2006-04-11 00:00:00.000000  98015-9945

# %%
#Q11- List faculty name and lastname who are not supervisor of other faculty.
txt='''
Select *
From Faculty
Where FAcNo NOT IN(
Select FacSupervisor
From Faculty
Where FacSupervisor is not null)
'''
Q11 =  psql.sqldf(txt)
Q11
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE  SEATTLE       WA      MS    ASST
# 1  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA      MS    ASST
# 2  987-65-4321        JULIA       MILLS  SEATTLE       WA     FIN    ASSC
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0      35000   654-32-1098  2004-04-10 00:00:00.000000  98111-9921
# 1      40000   654-32-1098  2008-03-01 00:00:00.000000  98114-1332
# 2      75000   765-43-2109  2009-03-15 00:00:00.000000  98114-9954

# %%
#Q12-Get number of faculty and average salary for each department.
txt='''
Select FacDept, COUNT(FacNo), AVG(FacSalary)
From Faculty
Group By FacDept
'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#   FacDept  COUNT(FacNo)  AVG(FacSalary)
# 0     FIN             2         70000.0
# 1      MS             4         66250.0

# %%
#Q13-Get number of faculty, number of course offered  for each faculty rank.
txt='''
Select FacRank, COUNT(Distinct Faculty.FacNo), COUNT(*)
From Faculty left join Offering on Faculty.FacNo=Offering.FacNo
Group By FacRank
'''
Q13 =  psql.sqldf(txt)
Q13
# Out:
#   FacRank  COUNT(Distinct Faculty.FacNo)  COUNT(*)
# 0    ASSC                              2         4
# 1    ASST                              2         4
# 2    PROF                              2         3

# %%
#For Q14.Q15,Q16 execute this cell first
import sqlite3

# Connecting to sqlite
conn = sqlite3.connect('gfs1.db')

# Creating a cursor object using
# the cursor() method
cursor = conn.cursor()

# Creating table
table = """CREATE TABLE Student
(StdNo CHAR(11),
StdFirstName VARCHAR(50),
StdLastName VARCHAR(50),
StdCity VARCHAR(50),
StdState CHAR(2),
StdZip CHAR(10),
StdMajor CHAR(6),
StdClass CHAR(6),
StdGPA DECIMAL(3,2),
CONSTRAINT PKStudent PRIMARY KEY (StdNo)  );"""
cursor.execute(table)

# %%
#For Q14,Q15 and Q16 execute earlier cell first.
#Q14-Insert a row into the Student table supplying following values for all columns.
#('487-44-1234', 'ELON', 'MUSK','SEATTLE','WA',98121-1111,'FIN','SO',3.9)
#('457-98-1234', 'BILL', 'GATES','REDMONT','WA',98116-2344,'IS','SR',3.8)
#into
# Student(StdNo,StdFirstName,StdLastName,StdCity,StdState,StdZip ,StdMajor,StdClass,StdGPA)
cursor.execute(
    '''
INSERT INTO Student (StdNo,StdFirstName,StdLastName,StdCity,StdState,StdZip ,StdMajor,StdClass,StdGPA)
VALUES ('487-44-1234', 'ELON', 'MUSK','SEATTLE','WA',98121-1111,'FIN','SO',3.9),
('457-98-1234', 'BILL', 'GATES','REDMONT','WA',98116-2344,'IS','SR',3.8)
    ''')
print("Student Table: ")
data = cursor.execute('''SELECT * FROM Student''')
for row in data:
    print(row)
conn.commit()
# Out:
# Student Table:
# ('487-44-1234', 'ELON', 'MUSK', 'SEATTLE', 'WA', '97010', 'FIN', 'SO', 3.9)
# ('457-98-1234', 'BILL', 'GATES', 'REDMONT', 'WA', '95772', 'IS', 'SR', 3.8)

# %%
 #Q15-Change  Elon Musk Student Grade to 4.0
 cursor.execute(
    '''
UPDATE Student
SET StdGPA=4.0
WHERE StdNo='487-44-1234'

    ''')

print("Student Table: ")
data = cursor.execute('''SELECT * FROM Student''')
for row in data:
    print(row)
conn.commit()
# Out:
# Student Table:
# ('487-44-1234', 'ELON', 'MUSK', 'SEATTLE', 'WA', '97010', 'FIN', 'SO', 4)
# ('457-98-1234', 'BILL', 'GATES', 'REDMONT', 'WA', '95772', 'IS', 'SR', 3.8)

# %%
 #Q16-Delete student with highest grade from Student Table
cursor.execute(
    '''
Delete From Student
Where StdGPA=(Select MAX(StdGPA)
From Student)

    ''')
print("Student Table: ")
data = cursor.execute('''SELECT * FROM Student''')
for row in data:
    print(row)
conn.commit()
# Out:
# Student Table:
# ('457-98-1234', 'BILL', 'GATES', 'REDMONT', 'WA', '95772', 'IS', 'SR', 3.8)
