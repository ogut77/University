# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/University/blob/main/QueryBlank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Course=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Course.xlsx?raw=true")
Faculty=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Faculty.xlsx?raw=true")
Student=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Student.xlsx?raw=true")
Enrollment=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Enrollment.xlsx?raw=true")
Offering=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Offering.xlsx?raw=true")
Faculty_1=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Faculty.xlsx?raw=true")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=de3caad567901e5adef7fcd01f120ec05d640e87c218e9118636d349bc2511ec
#   Stored in directory: /root/.cache/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SINGLE TABLE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A) Retrieve all columns from a table

# %%
#Query 1- List all columns and rows of the Faculty table.
# * display all fields (columns) for selected table
txt='''

'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          FacNo FacFirstName FacLastName   FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE   SEATTLE       WA      MS    ASST
# 1  543-21-0987     VICTORIA    EMMANUEL   BOTHELL       WA      MS    PROF
# 2  654-32-1098      LEONARD       FIBON   SEATTLE       WA      MS    ASSC
# 3  765-43-2109        NICKI       MACON  BELLEVUE       WA     FIN    PROF
# 4  876-54-3210   CRISTOPHER       COLAN   SEATTLE       WA      MS    ASST
# 5  987-65-4321        JULIA       MILLS   SEATTLE       WA     FIN    ASSC
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0      35000   654-32-1098  2004-04-10 00:00:00.000000  98111-9921
# 1     120000          None  2005-04-15 00:00:00.000000  98011-2242
# 2      70000   543-21-0987  2003-05-01 00:00:00.000000  98121-0094
# 3      65000          None  2006-04-11 00:00:00.000000  98015-9945
# 4      40000   654-32-1098  2008-03-01 00:00:00.000000  98114-1332
# ...

# %% [markdown]
# B) Retrieve some columns of a table example

# %%
#Query 2- List Faculty Name and Surname
txt='''

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#   FacFirstName FacLastName
# 0      LEONARD       VINCE
# 1     VICTORIA    EMMANUEL
# 2      LEONARD       FIBON
# 3        NICKI       MACON
# 4   CRISTOPHER       COLAN
# 5        JULIA       MILLS

# %% [markdown]
# C) Filter the result set- Exact Matching on a String Column with the = Operator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Query 3-List all columns of the course row with IS480 as the course number.
txt='''


'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#   CourseNo                              CrsDesc  CrsUnits
# 0    IS480  FUNDAMENTALS OF DATABASE MANAGEMENT         4

# %%
#Q4-List all information about course
# offerings scheduled in FALL 2016.
txt='''

'''
Q4 =  psql.sqldf(txt)
Q4
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0     1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1     4321    IS320    FALL     2016      BLM214  15:30:00.000000
#
#          FacNo OffDays
# 0  098-76-5432      MW
# 1  098-76-5432     TTH

# %%
#Query 5-List all information about
# course offerings scheduled in FALL 2016 or WINTER 2017.
txt='''


'''
Q5 =  psql.sqldf(txt)
Q5

# %%
#Query 6-  List all information about SUMMER 2017
#offerings WITHOUT an assigned instructor.
#Note: A field with a NULL value is a field with no value.
#IS NULL  or IS NOT NULL is used to filter a field with no value or with value respectively.
txt='''


'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime FacNo  \
# 0     1111    IS320  SUMMER     2017      BLM302  10:30:00.000000  None
#
#   OffDays
# 0      MW

# %%
#Query 6A- List all information about of SUMMER 2017
#offerings WITH an assigned instructor.
#Note: A field with a NULL value is a field with no value.
#IS NULL  or IS NOT NULL is used to filter a field with no value or with value respectively.
txt='''

'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0     8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
#
#          FacNo OffDays
# 0  654-32-1098      MW

# %% [markdown]
# D) Filter the result set with Comparision Operators

# %%
#Query 7-List the name, city, and grade point average (GPA) of students
# with a high GPA (greater than or equal to 3.7).
txt='''


'''
Q7 =  psql.sqldf(txt);Q7
# Out:
#   StdFirstName StdLastName  StdCity  StdGPA
# 0   CRISTOPHER       COLAN  SEATTLE     4.0
# 1      WILLIAM     PILGRIM  BOTHELL     3.8

# %%
#Q8- Retrieve the information of faculty whose salary is less than 75000 $
txt='''

'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#          FacNo FacFirstName FacLastName   FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE   SEATTLE       WA      MS    ASST
# 1  654-32-1098      LEONARD       FIBON   SEATTLE       WA      MS    ASSC
# 2  765-43-2109        NICKI       MACON  BELLEVUE       WA     FIN    PROF
# 3  876-54-3210   CRISTOPHER       COLAN   SEATTLE       WA      MS    ASST
#
#    FacSalary FacSupervisor                 FacHireDate  FacZipCode
# 0      35000   654-32-1098  2004-04-10 00:00:00.000000  98111-9921
# 1      70000   543-21-0987  2003-05-01 00:00:00.000000  98121-0094
# 2      65000          None  2006-04-11 00:00:00.000000  98015-9945
# 3      40000   654-32-1098  2008-03-01 00:00:00.000000  98114-1332

# %% [markdown]
# E) IN and NOT IN - Exact Matching on a String Column with the IN and NOT IN

# %%
#Query 9- Show all information of Junior ('JR') or sophomore ('SO') student.
txt='''

'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 1  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 2  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 3  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 4  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 5  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0      FIN       JR     2.7
# 1     ACCT       JR     3.5
# 2       IS       JR     3.6
# 3     ACCT       SO     3.3
# 4      FIN       JR     2.5
# 5       IS       SO     3.8

# %%
#Alternative to Q9- Show all information of Junior ('JR') or sophomore ('SO') student.
txt='''

'''
Q9 =  psql.sqldf(txt)
Q9

# %%
#Q10-Show all information of student
#whose major are not Accounting ('ACCT') and Finance ('FIN')
txt='''


'''
Q10=  psql.sqldf(txt)
Q10

# %%
#Alternative to Q10-Show all information of student whose major
#are not Accounting ('ACCT') and Finance ('FIN')
txt='''

'''
Q10A =  psql.sqldf(txt)
Q10A
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 2  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 3  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 4  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 5  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0       IS       FR     3.0
# 1       IS       SR     2.8
# 2       IS       JR     3.6
# 3       IS       SR     4.0
# 4       IS       SR     2.2
# 5       IS       SO     3.8

# %% [markdown]
# F) Eliminating Duplicates with DISTINCT

# %%
#Query 11-List the city and state of faculty members.
txt='''


'''
Q11 =  psql.sqldf(txt)
Q11
# Out:
#     FacCity FacState
# 0   SEATTLE       WA
# 1   BOTHELL       WA
# 2   SEATTLE       WA
# 3  BELLEVUE       WA
# 4   SEATTLE       WA
# 5   SEATTLE       WA

# %%
#Query 12- List the unique city and
#state combinations in the Faculty table.
txt='''


'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#     FacCity FacState
# 0   SEATTLE       WA
# 1   BOTHELL       WA
# 2  BELLEVUE       WA

# %% [markdown]
# G) Inexact Matching with the LIKE Operator Example

# %% [markdown]
# The LIKE operator is used in a WHERE clause to search for a specified pattern in a column.
#
# There are two wildcards often used in conjunction with the LIKE operator:
#
#  The percent sign (%) represents zero, one, or multiple characters.
#  The underscore sign (_) represents one, single character
#
# Note: MS Access uses an asterisk (*) instead of the percent sign (%), and a question mark (?) instead of the underscore (_).

# %%
#Query 13. List the senior-level IS courses. (Courses with starts with IS4)
txt='''


'''
Q13 =  psql.sqldf(txt)
Q13
# Out:
#   CourseNo                              CrsDesc  CrsUnits
# 0    IS460                     SYSTEMS ANALYSIS         4
# 1    IS470         BUSINESS DATA COMMUNICATIONS         4
# 2    IS480  FUNDAMENTALS OF DATABASE MANAGEMENT         4

# %%
#Query 14. List the courses containing
#the string “DATA” in the course description.
txt='''

'''
Q14 =  psql.sqldf(txt)
Q14
# Out:
#   CourseNo                              CrsDesc  CrsUnits
# 0    IS470         BUSINESS DATA COMMUNICATIONS         4
# 1    IS480  FUNDAMENTALS OF DATABASE MANAGEMENT         4

# %%
#Query 14A. List the courses containing
#the string “DATA” at the begining of course description.
txt='''



'''
Q14A =  psql.sqldf(txt)
Q14A

# %%
#Query 14B. List the courses containing
#the string “DATA” at the end of course description.
txt='''



'''
Q14B =  psql.sqldf(txt)
Q14B

# %%
#Query 14C. List the courses containing
#the string “DATA” at the middle of course description.
txt='''



'''
Q14C =  psql.sqldf(txt)
Q14C

# %%
#Query 15. List the name and rank
#of faculty with a five letter last name ending in “N”.
# Each question mark matches any single character.
txt='''



'''
Q15 =  psql.sqldf(txt)
Q15
# Out:
#          FacNo FacFirstName FacLastName  ... FacDept FacRank FacSalary
# 0  654-32-1098      LEONARD       FIBON  ...      MS    ASSC     70000
# 1  765-43-2109        NICKI       MACON  ...     FIN    PROF     65000
# 2  876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST     40000
#
# [3 rows x 8 columns]

# %%
#Query 15b. List faculty information whose next to last charachter in first name is I
# Each question mark matches any single character.
txt='''

'''
Q15b =  psql.sqldf(txt)
Q15b
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  543-21-0987     VICTORIA    EMMANUEL  BOTHELL       WA      MS    PROF
# 1  987-65-4321        JULIA       MILLS  SEATTLE       WA     FIN    ASSC
#
#    FacSalary
# 0     120000
# 1      75000

# %% [markdown]
# H) Sorting with Order By

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Query 16. -List the GPA, name, city and state of juniors.
#Order the result by GPA in ascending order.
txt='''



'''
Q16 =  psql.sqldf(txt)
Q16
# Out:
#    StdGPA StdFirstName StdLastName  StdCity StdState
# 0     2.5      ROBERTO     MORALES  SEATTLE       WA
# 1     2.7          BOB     NORBERT  BOTHELL       WA
# 2     3.5        CANDY     KENDALL   TACOMA       WA
# 3     3.6       MARIAH       DODGE  SEATTLE       WA

# %%
#Query 17. List the rank, salary, name, and
#department of faculty. Order the result by
# ascending (alphabetic) rank and descending salary.
txt='''



'''
Q17 =  psql.sqldf(txt)
Q17
# Out:
#   FacRank  FacSalary FacFirstName FacLastName FacDept
# 0    ASSC      75000        JULIA       MILLS     FIN
# 1    ASSC      70000      LEONARD       FIBON      MS
# 2    ASST      40000   CRISTOPHER       COLAN      MS
# 3    ASST      35000      LEONARD       VINCE      MS
# 4    PROF     120000     VICTORIA    EMMANUEL      MS
# 5    PROF      65000        NICKI       MACON     FIN

# %% [markdown]
# ## I) UNION, UNION ALL, INTERSECT, EXCEPT
# ![Slide5.png](data:image/png;base64,...)

# %% [markdown]
# # J)	Aggregate Function

# %%
#Query 18-List all Faculty and Student First and Last Name
txt='''

'''
Q18 =  psql.sqldf(txt)
Q18
# Out:
#      FirstName  LastName
# 0          BOB   NORBERT
# 1        CANDY   KENDALL
# 2   CRISTOPHER     COLAN
# 3        HOMER     WELLS
# 4          JOE   ESTRADA
# 5        JULIA     MILLS
# 6      LEONARD     FIBON
# 7      LEONARD     VINCE
# 8         LUKE    BRAZZI
# 9       MARIAH     DODGE
# 10       NICKI     MACON
# 11     ROBERTO   MORALES
# 12        TESS     DODGE
# 13    VICTORIA  EMMANUEL
# 14       WALLY   KENDALL
# 15     WILLIAM   PILGRIM

# %%
#Query 19-List all Faculty and Student First and Last Name. Include duplicates record as well
txt='''

'''
Q19 =  psql.sqldf(txt)
Q19
# Out:
#      FirstName  LastName
# 0      LEONARD     VINCE
# 1     VICTORIA  EMMANUEL
# 2      LEONARD     FIBON
# 3        NICKI     MACON
# 4   CRISTOPHER     COLAN
# 5        JULIA     MILLS
# 6        HOMER     WELLS
# 7          BOB   NORBERT
# 8        CANDY   KENDALL
# 9        WALLY   KENDALL
# 10         JOE   ESTRADA
# 11      MARIAH     DODGE
# 12        TESS     DODGE
# 13     ROBERTO   MORALES
# 14  CRISTOPHER     COLAN
# 15        LUKE    BRAZZI
# 16     WILLIAM   PILGRIM

# %%
#Query 20-List all Faculty and Student First and Last Name that exists both in Faculty and Student Table.
txt='''

'''
Q20 =  psql.sqldf(txt)
Q20
# Out:
#     FirstName LastName
# 0  CRISTOPHER    COLAN

# %%
#Query 21-List all Student First and Last Name
#whose name and surname does not appear in the Faculty Name and Surname.
txt='''

'''
Q21 =  psql.sqldf(txt)
Q21
# Out:
#   FirstName LastName
# 0       BOB  NORBERT
# 1     CANDY  KENDALL
# 2     HOMER    WELLS
# 3       JOE  ESTRADA
# 4      LUKE   BRAZZI
# 5    MARIAH    DODGE
# 6   ROBERTO  MORALES
# 7      TESS    DODGE
# 8     WALLY  KENDALL
# 9   WILLIAM  PILGRIM

# %%
#Query 22-List all Faculty  First and Last Name whose name and surname does not appear
#in the Student Name and Surname.
txt='''

'''
Q22 =  psql.sqldf(txt)
Q22
# Out:
#   FirstName  LastName
# 0     JULIA     MILLS
# 1   LEONARD     FIBON
# 2   LEONARD     VINCE
# 3     NICKI     MACON
# 4  VICTORIA  EMMANUEL

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Query 23. What is the average,
# minimum, maximum salary of Faculty ?
# How many faculty are there?
txt='''


'''
Q23 =  psql.sqldf(txt)
Q23
# Out:
#    AvgSalary  MinSalary  MaxSalary  FacultyNumber
# 0    67500.0      35000     120000              6

# %%
#Q24a-List all rows and columns of Offering Table
txt='''

'''
Q24a =  psql.sqldf(txt)
Q24a
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      1111    IS320  SUMMER     2017      BLM302  10:30:00.000000
# 1      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 2      2222    IS460  SUMMER     2016      BLM412  13:30:00.000000
# 3      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 4      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 5      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 6      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 7      5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 8      5679    IS480  SPRING     2017      BLM412  15:30:00.000000
# 9      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 10     7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 11     8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 12     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
#
#           FacNo OffDays
# ...

# %%
#Q24b-How many records are there in Offering Table
txt='''

'''
Q24b =  psql.sqldf(txt)
Q24b
# Out:
#    Number of Records
# 0                 13

# %%
#Q24c- In Offering Table, how many records have FacNo in FacNo Column?
txt='''

'''
Q24c =  psql.sqldf(txt)
Q24c
# Out:
#    Number of Records with FacNo
# 0                            11

# %%
#Q24d- In Offering Table, how many unique FacNo are there in FacNo Column?
txt='''

'''
Q24d =  psql.sqldf(txt)
Q24d
# Out:
#    Number of Unique FacNo
# 0                       6

# %% [markdown]
# # K) Summarizing Tables with GROUP BY and HAVING

# %%
#Query 25. Summarize the averageGPA of students and number of student by each major.
txt='''


'''
Q25 =  psql.sqldf(txt)
Q25
# Out:
#   StdMajor    AvgGPA  Number of Students
# 0     ACCT  3.400000                   2
# 1      FIN  2.800000                   3
# 2       IS  3.233333                   6

# %%
#Query 26. Summarize the number of offerings by year.
txt='''



'''
Q26 =  psql.sqldf(txt)
Q26
# Out:
#    OffYear  NumberofOffering
# 0     2016                 3
# 1     2017                10

# %%
#Query 27.
#Summarize the average GPA of upper division
#(junior or senior) students and  number of students  by each major.
txt='''


'''
Q27 =  psql.sqldf(txt)
Q27
# Out:
#   StdMajor  AvgGPA  Number of Student
# 0     ACCT    3.50                  1
# 1      FIN    2.80                  3
# 2       IS    3.15                  4

# %%
#Query 28 Summarize the minimum and maximum GPA of
#students by major and class. Include number of student in each major and class as well
txt='''


'''
Q28 =  psql.sqldf(txt)
Q28
# Out:
#   StdMajor StdClass  MinGPA  MaxGPA  Number of Student
# 0     ACCT       JR     3.5     3.5                  1
# 1     ACCT       SO     3.3     3.3                  1
# 2      FIN       JR     2.5     2.7                  2
# 3      FIN       SR     3.2     3.2                  1
# 4       IS       FR     3.0     3.0                  1
# 5       IS       JR     3.6     3.6                  1
# 6       IS       SO     3.8     3.8                  1
# 7       IS       SR     2.2     4.0                  3

# %%
#Query 29. List the number of upper-division
# students(junior or senior) and their average GPA.
txt='''


'''
Q29=  psql.sqldf(txt)
Q29
# Out:
#    AvgGPA  Number of Student
# 0  3.0625                  8

# %%
#Query 30a. Summarize the average GPA of upper-division
# (junior or senior) students by major and their number of each major.

txt='''




'''
Q30a=  psql.sqldf(txt)
Q30a
# Out:
#   StdMajor  avg(StdGPA)  count(*)
# 0     ACCT     3.400000         2
# 1      FIN     2.800000         3
# 2       IS     3.233333         6

# %%
#Query 30b. Summarize the average GPA of upper-division
# (junior or senior) students by major and their number of each major.
# Only list the majors with average GPA greater than 3.1.
#Note: HAVING Reminder: the HAVING clause must be preceded by the GROUP BY clause.
txt='''

'''
Q30b=  psql.sqldf(txt)
Q30b
# Out:
#   StdMajor  AVG(StdGPA)  Number of Student
# 0     ACCT         3.50                  1
# 1       IS         3.15                  4

# %%
#Query 30c. Summarize the average GPA of upper-division
# (junior or senior) students by major and their number of each major.
# Only list the majors having more than 1 students.
#Note: HAVING Reminder: the HAVING clause must be preceded by the GROUP BY clause.
txt='''

'''
Q30c=  psql.sqldf(txt)
Q30c
# Out:
#   StdMajor  AvgGPA  Number of Students
# 0      FIN    2.80                   3
# 1       IS    3.15                   4

# %% [markdown]
# TOP n ROWS- LIMIT Statement

# %%
# 'LIMIT n' is used to get TOP n rows. A LIMIT statement appears at the end of a query.
#Q31-List 3 student having highest GPA
txt='''

'''
Q31 =  psql.sqldf(txt)
Q31
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 1  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
# 2  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
#
#   StdMajor StdClass  StdGPA
# 0       IS       SR     4.0
# 1       IS       SO     3.8
# 2       IS       JR     3.6

# %%
#Q32-List information of faculty who has the highest salary
txt='''

'''
Q32 =  psql.sqldf(txt)
Q32
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  543-21-0987     VICTORIA    EMMANUEL  BOTHELL       WA      MS    PROF
#
#    FacSalary
# 0     120000

# %%
#Q32A-Get the second row of faculty if it is  ordered in descending by facsalary
#Use offset to access row with specific index(index start with 0)
txt='''

'''
Q32A =  psql.sqldf(txt)
Q32A
# Out:
#          FacNo FacFirstName FacLastName  FacCity FacState FacDept FacRank  \
# 0  987-65-4321        JULIA       MILLS  SEATTLE       WA     FIN    ASSC
#
#    FacSalary
# 0      75000

# %%
#Q32B-Get the second and third row of faculty if it is  ordered in descending by facsalary
#Use offset to access row with specific index(index start with 0)
txt='''

'''
Q32B =  psql.sqldf(txt)
Q32B

# %% [markdown]
# REVIEW

# %%
#Q33-Find course offering with no  Faculty number in FacFaculty Column.
txt='''

'''
Q33 =  psql.sqldf(txt)
Q33
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime FacNo  \
# 0     1111    IS320  SUMMER     2017      BLM302  10:30:00.000000  None
# 1     2222    IS460  SUMMER     2016      BLM412  13:30:00.000000  None
#
#   OffDays
# 0      MW
# 1     TTH

# %%
#Q34-Get the average gpa and number of IS student
txt='''

'''
Q34 =  psql.sqldf(txt)
Q34
# Out:
#    AvgStdGPA  Number of Student
# 0   3.233333                  6

# %%
#Q35-How many faculty are there for each rank?
#What is their average salary for each rank?
txt='''

'''
Q35 =  psql.sqldf(txt)
Q35
# Out:
#   FacRank  Number of Faculty  AvgFacSalary
# 0    ASSC                  2       72500.0
# 1    ASST                  2       37500.0
# 2    PROF                  2       92500.0

# %%
#Q36-Get number of student registered and
#their average enrollmet grade  for each offering?
txt='''

'''
Q36 =  psql.sqldf(txt)
Q36
# Out:
#    OfferNo  Number of Student Registered  AvgEnrGrade
# 0     1234                             6     3.383333
# 1     4321                             6     3.300000
# 2     5555                             2     2.950000
# 3     5678                             5     3.060000
# 4     5679                             6     3.133333
# 5     6666                             2     3.350000
# 6     7777                             3     3.500000
# 7     9876                             7     3.314286

# %%
#Q37-List number of offering per semester and year
txt='''

'''
Q37 =  psql.sqldf(txt)
Q37
# Out:
#   OffTerm  OffYear  Number of Course Offered
# 0    FALL     2016                         2
# 1  SPRING     2017                         4
# 2  SUMMER     2016                         1
# 3  SUMMER     2017                         2
# 4  WINTER     2017                         4

# %%
#Q38-List number of offering per semester and year
# if there are more than 2 offering for each semester and year.
txt='''

'''
Q38 =  psql.sqldf(txt)
Q38
# Out:
#   OffTerm  OffYear  Number of Course Offered
# 0  SPRING     2017                         4
# 1  WINTER     2017                         4

# %%
#Q39-Get the average gpa and number of IS and FIN  student
txt='''

'''
Q39 =  psql.sqldf(txt)
Q39
# Out:
#   StdMajor  Number of Student  AvgStdGPA
# 0      FIN                  3   2.800000
# 1       IS                  6   3.233333

# %%
#Q40-Find student related information if StdZip starts with 98121
txt='''

'''
Q40 =  psql.sqldf(txt)
Q40
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 2  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
#
#   StdMajor StdClass  StdGPA
# 0       IS       FR     3.0
# 1      FIN       SR     3.2
# 2      FIN       JR     2.5
