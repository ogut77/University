# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Course=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Course.xlsx?raw=true")
Faculty=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Faculty.xlsx?raw=true")
Student=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Student.xlsx?raw=true")
Enrollment=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Enrollment.xlsx?raw=true")
Offering=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Offering.xlsx?raw=true")
Faculty_1=pd.read_excel("https://raw.githubusercontent.com/ogut77/University/master/Faculty.xlsx?raw=true")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=ae73c0f8289e3aa293a58a21aa8ca050c2168ae7193b2a2a77e3241351eb12f5
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %% [markdown]
# ![Gemini_Generated_Image_aytco2aytco2aytc.png](data:image/png;base64,...)

# %%
#Q1-List all rows and columns of student table
txt='''

'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#           StdNo StdFirstName StdLastName  ... StdMajor StdClass StdGPA
# 0   123-45-6789        HOMER       WELLS  ...       IS       FR    3.0
# 1   124-56-7890          BOB     NORBERT  ...      FIN       JR    2.7
# 2   234-56-7890        CANDY     KENDALL  ...     ACCT       JR    3.5
# 3   345-67-8901        WALLY     KENDALL  ...       IS       SR    2.8
# 4   456-78-9012          JOE     ESTRADA  ...      FIN       SR    3.2
# 5   567-89-0123       MARIAH       DODGE  ...       IS       JR    3.6
# 6   678-90-1234         TESS       DODGE  ...     ACCT       SO    3.3
# 7   789-01-2345      ROBERTO     MORALES  ...      FIN       JR    2.5
# 8   876-54-3210   CRISTOPHER       COLAN  ...       IS       SR    4.0
# 9   890-12-3456         LUKE      BRAZZI  ...       IS       SR    2.2
# 10  901-23-4567      WILLIAM     PILGRIM  ...       IS       SO    3.8
#
# [11 rows x 9 columns]

# %%
#Q2-List student first name and last name
txt='''

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#    StdFirstName StdLastName
# 0         HOMER       WELLS
# 1           BOB     NORBERT
# 2         CANDY     KENDALL
# 3         WALLY     KENDALL
# 4           JOE     ESTRADA
# 5        MARIAH       DODGE
# 6          TESS       DODGE
# 7       ROBERTO     MORALES
# 8    CRISTOPHER       COLAN
# 9          LUKE      BRAZZI
# 10      WILLIAM     PILGRIM

# %%
#Q3-List student first name and last name whose major is 'IS'
txt='''


'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#   StdFirstName StdLastName
# 0        HOMER       WELLS
# 1        WALLY     KENDALL
# 2       MARIAH       DODGE
# 3   CRISTOPHER       COLAN
# 4         LUKE      BRAZZI
# 5      WILLIAM     PILGRIM

# %%
#Q4-List student first name and last name whose major is 'ACCT' and student class is sophomere ('SO')
txt='''

'''
Q4 =  psql.sqldf(txt)
Q4
# Out:
#   StdFirstName StdLastName
# 0         TESS       DODGE

# %%
#Q5-List all student with student GPA is greater than 3.1
txt='''

'''
Q5 =  psql.sqldf(txt)
Q5
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 1  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 2  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 3  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 4  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 5  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0     ACCT       JR     3.5
# 1      FIN       SR     3.2
# 2       IS       JR     3.6
# 3     ACCT       SO     3.3
# 4       IS       SR     4.0
# 5       IS       SO     3.8

# %%
#Q6-List all student with student GPA is between 3.3 and 3.8 (3.3 and 3.8 is included)
txt='''

'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 1  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 2  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 3  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#   StdMajor StdClass  StdGPA
# 0     ACCT       JR     3.5
# 1       IS       JR     3.6
# 2     ACCT       SO     3.3
# 3       IS       SO     3.8

# %%
#Q7-List unique faculty department
txt='''

'''
Q7 =  psql.sqldf(txt)
Q7
# Out:
#   FacDept
# 0      MS
# 1     FIN

# %%
#Q8-List all faculty information if faculty rank  is ASST or ASSC
txt='''

'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#          FacNo FacFirstName FacLastName  ... FacDept FacRank FacSalary
# 0  098-76-5432      LEONARD       VINCE  ...      MS    ASST     35000
# 1  654-32-1098      LEONARD       FIBON  ...      MS    ASSC     70000
# 2  876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST     40000
# 3  987-65-4321        JULIA       MILLS  ...     FIN    ASSC     75000
#
# [4 rows x 8 columns]

# %%
#Q9-List all faculty information when faculty rank is not  ASST and ASSC
txt='''

'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#          FacNo FacFirstName FacLastName  ... FacDept FacRank FacSalary
# 0  543-21-0987     VICTORIA    EMMANUEL  ...      MS    PROF    120000
# 1  765-43-2109        NICKI       MACON  ...     FIN    PROF     65000
#
# [2 rows x 8 columns]

# %%
#Q10-List  courses related information
#for the courses containing the string 'BUSINESS' in the course description.
txt='''

'''
Q10 =  psql.sqldf(txt)
Q10
# Out:
#   CourseNo                               CrsDesc  CrsUnits
# 0    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING         4
# 1    IS470          BUSINESS DATA COMMUNICATIONS         4
