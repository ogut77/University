# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Course=pd.read_excel("https://github.com/ogut77/University/blob/main/Course.xlsx?raw=true")
Faculty=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty.xlsx?raw=true")
Student=pd.read_excel("https://github.com/ogut77/University/blob/main/Student.xlsx?raw=true")
Enrollment=pd.read_excel("https://github.com/ogut77/University/blob/main/Enrollment.xlsx?raw=true")
Offering=pd.read_excel("https://github.com/ogut77/University/blob/main/Offering.xlsx?raw=true")
Faculty_1=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty_1.xlsx?raw=true")

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %%
#Query 1- List all columns and rows of the Faculty table. 
txt='''
SELECT * 
FROM Faculty
'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#          FacNo FacFirstName FacLastName  ... FacDept FacRank FacSalary
# 0  098-76-5432      LEONARD       VINCE  ...      MS    ASST     35000
# 1  543-21-0987     VICTORIA    EMMANUEL  ...      MS    PROF    120000
# 2  654-32-1098      LEONARD       FIBON  ...      MS    ASSC     70000
# 3  765-43-2109        NICKI       MACON  ...     FIN    PROF     65000
# 4  876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST     40000
# 5  987-65-4321        JULIA       MILLS  ...     FIN    ASSC     75000
#
# [6 rows x 8 columns]

# %%
#Query 2- List Faculty Name and Surname
txt='''
SELECT FacFirstName,	FacLastName
FROM Faculty'''
sdf =  psql.sqldf(txt);sdf
# Out:
#   FacFirstName FacLastName
# 0      LEONARD       VINCE
# 1     VICTORIA    EMMANUEL
# 2      LEONARD       FIBON
# 3        NICKI       MACON
# 4   CRISTOPHER       COLAN
# 5        JULIA       MILLS

# %%
Course
# Out:
#   CourseNo                               CrsDesc  CrsUnits
# 0   FIN300               FUNDAMENTALS OF FINANCE         4
# 1   FIN450             PRINCIPLES OF INVESTMENTS         4
# 2   FIN480                     CORPORATE FINANCE         4
# 3    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING         4
# 4    IS460                      SYSTEMS ANALYSIS         4
# 5    IS470          BUSINESS DATA COMMUNICATIONS         4
# 6    IS480   FUNDAMENTALS OF DATABASE MANAGEMENT         4

# %%
#Query 3-List all columns of the course row with IS480 as the course number.
txt='''
SELECT *
FROM Course
WHERE Courseno LIKE  '____0'
'''
sdf =  psql.sqldf(txt);sdf
# Out:
#   CourseNo                               CrsDesc  CrsUnits
# 0    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING         4
# 1    IS460                      SYSTEMS ANALYSIS         4
# 2    IS470          BUSINESS DATA COMMUNICATIONS         4
# 3    IS480   FUNDAMENTALS OF DATABASE MANAGEMENT         4

# %%
#Q4-List the offer number, course number, and faculty number for course
# offerings scheduled in fall 2016.
txt='''
SELECT *
FROM Offering 
WHERE OffYear='2016' and OffTerm='FALL'
'''
sdf =  psql.sqldf(txt);sdf
# Out:
#    OfferNo CourseNo OffTerm  ...          OffTime        FacNo OffDays
# 0     1234    IS320    FALL  ...  10:30:00.000000  098-76-5432      MW
# 1     4321    IS320    FALL  ...  15:30:00.000000  098-76-5432     TTH
#
# [2 rows x 8 columns]
