# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Course=pd.read_excel("https://github.com/ogut77/University/blob/main/Course.xlsx?raw=true")
Faculty=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty.xlsx?raw=true")
Student=pd.read_excel("https://github.com/ogut77/University/blob/main/Student.xlsx?raw=true")
Enrollment=pd.read_excel("https://github.com/ogut77/University/blob/main/Enrollment.xlsx?raw=true")
Offering=pd.read_excel("https://github.com/ogut77/University/blob/main/Offering.xlsx?raw=true")
Faculty_1=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty_1.xlsx?raw=true")
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=f0aaee6c90005abb7553f37469af84c06239da866dd305a890cb55718a165b14
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A **primary key** is a column of table which uniquely identifies each tuple (row) in that table. The primary key does not accept the any duplicate and NULL values.
#
#
# A **foreign key** is a column or group of columns in a relational database table that provides a link between data in two tables.
# It is most often the the primary key of another table.

# %%
#Query 1-List all student info and
#their enrollment grade from a course(Just use two tables)
txt='''

'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#           StdNo StdFirstName StdLastName  ... OfferNo        StdNo EnrGrade
# 0   123-45-6789        HOMER       WELLS  ...    1234  123-45-6789      3.3
# 1   123-45-6789        HOMER       WELLS  ...    4321  123-45-6789      3.5
# 2   123-45-6789        HOMER       WELLS  ...    5555  123-45-6789      3.2
# 3   123-45-6789        HOMER       WELLS  ...    5678  123-45-6789      3.2
# 4   123-45-6789        HOMER       WELLS  ...    5679  123-45-6789      2.0
# 5   124-56-7890          BOB     NORBERT  ...    4321  124-56-7890      3.2
# 6   124-56-7890          BOB     NORBERT  ...    5555  124-56-7890      2.7
# 7   124-56-7890          BOB     NORBERT  ...    5679  124-56-7890      3.7
# 8   124-56-7890          BOB     NORBERT  ...    9876  124-56-7890      3.5
# 9   234-56-7890        CANDY     KENDALL  ...    1234  234-56-7890      3.5
# 10  234-56-7890        CANDY     KENDALL  ...    5678  234-56-7890      2.8
# ...

# %%
#Query 2-Get the grades of student with 
#Student No '123-45-6789' 
txt='''
 
'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#          StdNo StdFirstName StdLastName  ... StdGPA OfferNo EnrGrade
# 0  123-45-6789        HOMER       WELLS  ...    3.0    1234      3.3
# 1  123-45-6789        HOMER       WELLS  ...    3.0    4321      3.5
# 2  123-45-6789        HOMER       WELLS  ...    3.0    5555      3.2
# 3  123-45-6789        HOMER       WELLS  ...    3.0    5678      3.2
# 4  123-45-6789        HOMER       WELLS  ...    3.0    5679      2.0
#
# [5 rows x 11 columns]

# %%
#Query 3-List the StdNo, student name, offering number,enrollment grade
# of students who have a grade ≥ 3.5 in a course offering.
txt='''

'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#          StdNo StdFirstName StdLastName  OfferNo  EnrGrade
# 0  234-56-7890        CANDY     KENDALL     1234       3.5
# 1  567-89-0123       MARIAH       DODGE     1234       3.8
# 2  123-45-6789        HOMER       WELLS     4321       3.5
# 3  789-01-2345      ROBERTO     MORALES     4321       3.5
# 4  124-56-7890          BOB     NORBERT     5679       3.7
# 5  789-01-2345      ROBERTO     MORALES     5679       3.8
# 6  567-89-0123       MARIAH       DODGE     6666       3.6
# 7  890-12-3456         LUKE      BRAZZI     7777       3.7
# 8  124-56-7890          BOB     NORBERT     9876       3.5
# 9  901-23-4567      WILLIAM     PILGRIM     9876       4.0

# %%
#Query 4-Get the course offering information and instructor's  
#first and last name of that course offering.List only if instructor is known. 
txt='''

'''
Q4=  psql.sqldf(txt)
Q4
# Out:
#     OfferNo CourseNo OffTerm  ...  OffDays FacFirstName FacLastName
# 0      1234    IS320    FALL  ...       MW      LEONARD       VINCE
# 1      3333    IS320  SPRING  ...       MW      LEONARD       VINCE
# 2      4321    IS320    FALL  ...      TTH      LEONARD       VINCE
# 3      4444    IS320  WINTER  ...      TTH     VICTORIA    EMMANUEL
# 4      5555   FIN300  WINTER  ...       MW        NICKI       MACON
# 5      5678    IS480  WINTER  ...       MW        JULIA       MILLS
# 6      5679    IS480  SPRING  ...      TTH   CRISTOPHER       COLAN
# 7      6666   FIN450  WINTER  ...      TTH        JULIA       MILLS
# 8      7777   FIN480  SPRING  ...       MW        NICKI       MACON
# 9      8888    IS320  SUMMER  ...       MW      LEONARD       FIBON
# 10     9876    IS460  SPRING  ...      TTH      LEONARD       FIBON
#
# [11 rows x 10 columns]

# %%
#Query 5-Same as Query 4 but add Course Description.
#In other words, list the course offering,
#faculty name, surname and course description. List only if instructor is known. 
txt='''

'''
Q5 =  psql.sqldf(txt)
Q5
# Out:
#     OfferNo CourseNo  ... FacLastName                               CrsDesc
# 0      1234    IS320  ...       VINCE  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 1      3333    IS320  ...       VINCE  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 2      4321    IS320  ...       VINCE  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 3      4444    IS320  ...    EMMANUEL  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 4      5555   FIN300  ...       MACON               FUNDAMENTALS OF FINANCE
# 5      5678    IS480  ...       MILLS   FUNDAMENTALS OF DATABASE MANAGEMENT
# 6      5679    IS480  ...       COLAN   FUNDAMENTALS OF DATABASE MANAGEMENT
# 7      6666   FIN450  ...       MILLS             PRINCIPLES OF INVESTMENTS
# 8      7777   FIN480  ...       MACON                     CORPORATE FINANCE
# 9      8888    IS320  ...       FIBON  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 10     9876    IS460  ...       FIBON                      SYSTEMS ANALYSIS
#
# [11 rows x 11 columns]

# %%
#Query 6-Same as Query 1 but add Course Description to the table 
#In other words,List all student info,
#their enrollment grade from a course and course description.List only if instructor is known. 
txt='''

'''
Q6 =  psql.sqldf(txt)
Q6
# Out:
#           StdNo StdFirstName  ... CourseNo                               CrsDesc
# 0   123-45-6789        HOMER  ...    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 1   123-45-6789        HOMER  ...    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 2   123-45-6789        HOMER  ...   FIN300               FUNDAMENTALS OF FINANCE
# 3   123-45-6789        HOMER  ...    IS480   FUNDAMENTALS OF DATABASE MANAGEMENT
# 4   123-45-6789        HOMER  ...    IS480   FUNDAMENTALS OF DATABASE MANAGEMENT
# 5   124-56-7890          BOB  ...    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 6   124-56-7890          BOB  ...   FIN300               FUNDAMENTALS OF FINANCE
# 7   124-56-7890          BOB  ...    IS480   FUNDAMENTALS OF DATABASE MANAGEMENT
# 8   124-56-7890          BOB  ...    IS460                      SYSTEMS ANALYSIS
# 9   234-56-7890        CANDY  ...    IS320  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 10  234-56-7890        CANDY  ...    IS480   FUNDAMENTALS OF DATABASE MANAGEMENT
# ...

# %%
#Query 7-Same as Query 6 and add Faculty First Name and Faculty Last Name to the table 
#
txt='''

'''
Q7 =  psql.sqldf(txt)
Q7
# Out:
#           StdNo StdFirstName  ... FacFirstName FacLastName
# 0   123-45-6789        HOMER  ...      LEONARD       VINCE
# 1   123-45-6789        HOMER  ...      LEONARD       VINCE
# 2   123-45-6789        HOMER  ...        NICKI       MACON
# 3   123-45-6789        HOMER  ...        JULIA       MILLS
# 4   123-45-6789        HOMER  ...   CRISTOPHER       COLAN
# 5   124-56-7890          BOB  ...      LEONARD       VINCE
# 6   124-56-7890          BOB  ...        NICKI       MACON
# 7   124-56-7890          BOB  ...   CRISTOPHER       COLAN
# 8   124-56-7890          BOB  ...      LEONARD       FIBON
# 9   234-56-7890        CANDY  ...      LEONARD       VINCE
# 10  234-56-7890        CANDY  ...        JULIA       MILLS
# 11  234-56-7890        CANDY  ...        JULIA       MILLS
# 12  234-56-7890        CANDY  ...      LEONARD       FIBON
# 13  345-67-8901        WALLY  ...      LEONARD       VINCE
# 14  345-67-8901        WALLY  ...        JULIA       MILLS
# ...

# %%
#Query 8-List Leonard Vince’s teaching schedule
# in fall 2016. For each course, 
#list the offering number, course number,Term,Year, location,time and days.
txt='''

'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0     1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1     4321    IS320    FALL     2016      BLM214  15:30:00.000000
#
#          FacNo OffDays
# 0  098-76-5432      MW
# 1  098-76-5432     TTH

# %%
#Query 9-In addition to Query 8, add Course Description to the Table.
txt='''


'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0     1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1     4321    IS320    FALL     2016      BLM214  15:30:00.000000
#
#          FacNo OffDays                               CrsDesc
# 0  098-76-5432      MW  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 1  098-76-5432     TTH  FUNDAMENTALS OF BUSINESS PROGRAMMING

# %%
#Query 10-List Student Bob Norbert’s course schedule in 
#spring 2017. For each course, list the offering number,
# course number, days, location, time and instructor's name.
txt='''


'''
Q10 =  psql.sqldf(txt)
Q10
# Out:
#    OfferNo CourseNo OffTerm  ...  OffDays FacFirstName FacLastName
# 0     5679    IS480  SPRING  ...      TTH   CRISTOPHER       COLAN
# 1     9876    IS460  SPRING  ...      TTH      LEONARD       FIBON
#
# [2 rows x 10 columns]

# %%
#Query 11-List the course number,the offering number, 
# the number of students enrolled and offering's average enrollment grade. 
 
txt='''


'''
Q11 =  psql.sqldf(txt)
Q11
# Out:
#    OfferNo CourseNo  NoOfStudents  AvgEnrGrade
# 0     1234    IS320             6     3.383333
# 1     4321    IS320             6     3.300000
# 2     5555   FIN300             2     2.950000
# 3     5678    IS480             5     3.060000
# 4     5679    IS480             6     3.133333
# 5     6666   FIN450             2     3.350000
# 6     7777   FIN480             3     3.500000
# 7     9876    IS460             7     3.314286

# %%
#Query 12-List the course number, offer number,
# and average enrollment grade for course offerings  in which 
#the average enrollment grade is greater than 3.2
txt='''

'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#    OfferNo CourseNo  NoOfStudents  AvgEnrGrade
# 0     1234    IS320             6     3.383333
# 1     4321    IS320             6     3.300000
# 2     6666   FIN450             2     3.350000
# 3     7777   FIN480             3     3.500000
# 4     9876    IS460             7     3.314286

# %% [markdown]
# # **REVIEW**

# %%
#List number of offering per year
txt='''

'''
QR1 =  psql.sqldf(txt)
QR1
# Out:
#    OffYear  NoOfOffering
# 0     2016             3
# 1     2017            10

# %%
#List number of offering per semester and year
txt='''

'''
QR2 =  psql.sqldf(txt)
QR2
# Out:
#    OffYear OffTerm  NoOfOffering
# 0     2016    FALL             2
# 1     2016  SUMMER             1
# 2     2017  SPRING             4
# 3     2017  SUMMER             2
# 4     2017  WINTER             4

# %%
#List number of offering and average enrollment grade per semester
#OffYear,OffTerm,count(*) AS NoOfOffering, AVG(EnrGrade) As AvgGrade
txt='''


'''
QR3 =  psql.sqldf(txt)
QR3
# Out:
#    OffYear OffTerm  count(Distinct Enrollment.OfferNo)  Avg(EnrGrade)
# 0     2016    FALL                                   2       3.341667
# 1     2017  SPRING                                   3       3.281250
# 2     2017  WINTER                                   3       3.100000

# %% [markdown]
# ## Update, Insert,Delete

# %% [markdown]
# DELETE FROM table_name WHERE condition
#
# INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...)
#
# UPDATE table_name
# SET column1 = value1, column2 = value2, ...
# WHERE condition;

# %%
import sqlite3
  
# Connecting to sqlite
conn = sqlite3.connect('gfs1a.db')
  
# Creating a cursor object using 
# the cursor() method
cursor = conn.cursor()
  
# Creating table
table = """CREATE TABLE COURSE(CourseNo VARCHAR(255), 
CrsDesc VARCHAR(255),CrsUnits int,PRIMARY KEY (CourseNo));"""
cursor.execute(table)

# %%
# Queries to INSERT records.
cursor.execute(
    '''INSERT INTO COURSE(CourseNo,CrsDesc,CrsUnits) 
    VALUES ('FIN300',	'FUNDAMENTALS OF FINANCE',	4),
    ('FIN450',	'PRINCIPLES OF INVESTMENTS',	4),
    ('FIN480',	'CORPORATE FINANCE',	4),
    ('IS320',	'FUNDAMENTALS OF BUSINESS PROGRAMMING',	4),
       ('IS460',	'SYSTEMS ANALYSIS',	4),
       ('IS470',	'BUSINESS DATA COMMUNICATIONS',	4),
       ('IS480',	'FUNDAMENTALS OF DATABASE MANAGEMENT',	4)

    ''')



  
# Display data inserted
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
  
conn.commit()
# Out:
# COURSE Table:
# ('FIN300', 'FUNDAMENTALS OF FINANCE', 4)
# ('FIN450', 'PRINCIPLES OF INVESTMENTS', 4)
# ('FIN480', 'CORPORATE FINANCE', 4)
# ('IS320', 'FUNDAMENTALS OF BUSINESS PROGRAMMING', 4)
# ('IS460', 'SYSTEMS ANALYSIS', 4)
# ('IS470', 'BUSINESS DATA COMMUNICATIONS', 4)
# ('IS480', 'FUNDAMENTALS OF DATABASE MANAGEMENT', 4)

# %%
#Insert a row into the Course table supplying following values for all columns.
#('IS380', 'MANAGEMENT INFORMATION SYSTEMS', 4) into
# COURSE(CourseNo,CrsDesc,CrsUnits) 

cursor.execute(
    '''
 
    
    ''')
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()
# Out:
# COURSE Table:
# ('FIN300', 'FUNDAMENTALS OF FINANCE', 4)
# ('FIN450', 'PRINCIPLES OF INVESTMENTS', 4)
# ('FIN480', 'CORPORATE FINANCE', 4)
# ('IS320', 'FUNDAMENTALS OF BUSINESS PROGRAMMING', 4)
# ('IS460', 'SYSTEMS ANALYSIS', 4)
# ('IS470', 'BUSINESS DATA COMMUNICATIONS', 4)
# ('IS480', 'FUNDAMENTALS OF DATABASE MANAGEMENT', 4)
# ('IS380', 'MANAGEMENT INFORMATION SYSTEMS', 4)

# %%
#Change the the name of 'MANAGEMENT INFORMATION SYSTEMS' 
# to 'INFORMATION SYSTEMS' for CourseNo 'IS380'

cursor.execute(
    
'''

''')

# Display data
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()
# Out:
# COURSE Table:
# ('FIN300', 'FUNDAMENTALS OF FINANCE', 4)
# ('FIN450', 'PRINCIPLES OF INVESTMENTS', 4)
# ('FIN480', 'CORPORATE FINANCE', 4)
# ('IS320', 'FUNDAMENTALS OF BUSINESS PROGRAMMING', 4)
# ('IS460', 'SYSTEMS ANALYSIS', 4)
# ('IS470', 'BUSINESS DATA COMMUNICATIONS', 4)
# ('IS480', 'FUNDAMENTALS OF DATABASE MANAGEMENT', 4)
# ('IS380', 'INFORMATION SYSTEMS', 4)

# %%
#Delete row with  the the name of 'MANAGEMENT INFORMATION SYSTEMS' and
#CourseNo 'IS380'.
cursor.execute(
'''

''')
# Display data
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()
# Out:
# COURSE Table:
# ('FIN300', 'FUNDAMENTALS OF FINANCE', 4)
# ('FIN450', 'PRINCIPLES OF INVESTMENTS', 4)
# ('FIN480', 'CORPORATE FINANCE', 4)
# ('IS320', 'FUNDAMENTALS OF BUSINESS PROGRAMMING', 4)
# ('IS460', 'SYSTEMS ANALYSIS', 4)
# ('IS470', 'BUSINESS DATA COMMUNICATIONS', 4)
# ('IS480', 'FUNDAMENTALS OF DATABASE MANAGEMENT', 4)

# %%
#ADD Column Name with PreRequisite 
cursor.execute(
'''


''')
# Display data
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()
#SQL does not all to modify table names and constraint
#and drop columns. For workaround you can check
#https://stackoverflow.com/questions/8442147/how-to-delete-or-add-column-in-sqlite

# %%
# Add FIN300 As PreRequisite for FIN480

cursor.execute(
    
'''
'

''')

# Display data
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()

# %%
#Delete all rows.
cursor.execute(
'''


''')

# Display data
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()
# Out:
# COURSE Table:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Queries to INSERT records.
cursor.execute(
    '''INSERT INTO COURSE(CourseNo,CrsDesc,CrsUnits) 
    VALUES ('FIN300',	'FUNDAMENTALS OF FINANCE',	4),
    ('FIN450',	'PRINCIPLES OF INVESTMENTS',	4),
    ('FIN480',	'CORPORATE FINANCE',	4),
    ('IS320',	'FUNDAMENTALS OF BUSINESS PROGRAMMING',	4),
       ('IS460',	'SYSTEMS ANALYSIS',	4),
       ('IS470',	'BUSINESS DATA COMMUNICATIONS',	4),
       ('IS480',	'FUNDAMENTALS OF DATABASE MANAGEMENT',	4)

    ''')



  
# Display data inserted
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
  
conn.commit()
# Out:
# COURSE Table:
# ('FIN300', 'FUNDAMENTALS OF FINANCE', 4)
# ('FIN450', 'PRINCIPLES OF INVESTMENTS', 4)
# ('FIN480', 'CORPORATE FINANCE', 4)
# ('IS320', 'FUNDAMENTALS OF BUSINESS PROGRAMMING', 4)
# ('IS460', 'SYSTEMS ANALYSIS', 4)
# ('IS470', 'BUSINESS DATA COMMUNICATIONS', 4)
# ('IS480', 'FUNDAMENTALS OF DATABASE MANAGEMENT', 4)

# %%
#Drop Table COURSE
cursor.execute(
'''
DROP TABLE COURSE 

''')
# Display data
print("COURSE Table: ")
data = cursor.execute('''SELECT * FROM COURSE''')
for row in data:
    print(row)
conn.commit()
# Out:
# COURSE Table:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-37-8e91bd070742> in <module>()
#       7 # Display data
#       8 print("COURSE Table: ")
# ----> 9 data = cursor.execute('''SELECT * FROM COURSE''')
#      10 for row in data:
#      11     print(row)
#
# OperationalError: no such table: COURSE

# %% [markdown]
# ### **JOIN**

# %% [markdown]
# ![sqlJoins_7.png](data:image/png;base64,...)

# %% [markdown]
# #Inner Join: Includes only common rows from table 1 and 2
#
# SELECT column_name(s)
# FROM table1
# INNER JOIN table2
# ON table1.column_name = table2.column_name
#
# #Left Join : Include all rows from table 1 and matching rows from table 2
# SELECT column_name(s)
# FROM table1
# LEFT JOIN table2
# ON table1.column_name = table2.column_name
#
# #Right Join : Include all rows from table 1 and matching rows from table 2
# SELECT column_name(s)
# FROM table1
# RIGHT JOIN table2
# ON table1.column_name = table2.column_name
#
# #Full Outer Join : Include all rows from table 1 and table 2
# SELECT column_name(s)
# FROM table1
# FULL OUTER  JOIN table2
# ON table1.column_name = table2.column_name
#
# #Cross Join:A record in table1 is paired with all record on table 2
# SELECT column_name(s)
# FROM table1,table2
#
# #NOT 1: INNER JOIN is the same as
#
# SELECT column_name(s)
# FROM table1,table2
# WHERE table1.column_name = table2.column_name
#
#
# #NOT 2: Right join and Full Outer Join is not supported in Sql lite
# #For right join, you can use
#
# SELECT column_name(s)
# FROM table2
# LEFT JOIN table1
# ON table1.column_name = table2.column_name

# %%
#Select Faculty and Student related inofrmation where person are both faculty and student
txt='''


'''
Q13 =  psql.sqldf(txt)
Q13
# Out:
#          StdNo StdFirstName StdLastName  ... FacDept FacRank FacSalary
# 0  876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST     40000
#
# [1 rows x 17 columns]

# %%
#Q17A-(Inner Join Method)
#Select Faculty and Student related inofrmation whore are both faculty and student 
txt='''

'''
Q13A =  psql.sqldf(txt)
Q13A
# Out:
#          StdNo StdFirstName StdLastName  ... FacDept FacRank FacSalary
# 0  876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST     40000
#
# [1 rows x 17 columns]

# %%
#Select All  Student Information. If Student is Faculty, show that student's faculty related information
txt='''

'''
Q14 =  psql.sqldf(txt)
Q14
# Out:
#           StdNo StdFirstName StdLastName  ... FacDept FacRank FacSalary
# 0   123-45-6789        HOMER       WELLS  ...    None    None       NaN
# 1   124-56-7890          BOB     NORBERT  ...    None    None       NaN
# 2   234-56-7890        CANDY     KENDALL  ...    None    None       NaN
# 3   345-67-8901        WALLY     KENDALL  ...    None    None       NaN
# 4   456-78-9012          JOE     ESTRADA  ...    None    None       NaN
# 5   567-89-0123       MARIAH       DODGE  ...    None    None       NaN
# 6   678-90-1234         TESS       DODGE  ...    None    None       NaN
# 7   789-01-2345      ROBERTO     MORALES  ...    None    None       NaN
# 8   876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST   40000.0
# 9   890-12-3456         LUKE      BRAZZI  ...    None    None       NaN
# 10  901-23-4567      WILLIAM     PILGRIM  ...    None    None       NaN
#
# [11 rows x 17 columns]

# %%
#Select All  Faculty Information. If Faculty is Student, show that Faculty's student related information
txt='''

'''
Q15 =  psql.sqldf(txt)
Q15
# Out:
#          StdNo StdFirstName StdLastName  ... FacDept FacRank FacSalary
# 0         None         None        None  ...      MS    ASST     35000
# 1         None         None        None  ...      MS    PROF    120000
# 2         None         None        None  ...      MS    ASSC     70000
# 3         None         None        None  ...     FIN    PROF     65000
# 4  876-54-3210   CRISTOPHER       COLAN  ...      MS    ASST     40000
# 5         None         None        None  ...     FIN    ASSC     75000
#
# [6 rows x 17 columns]

# %%
#Show Course Offering and Faculty Last Name and First Name.
# If Faculty is not assigned to course offering, show that as well.
txt='''

'''
Q16 =  psql.sqldf(txt)
Q16
# Out:
#     OfferNo CourseNo OffTerm  ...  OffDays FacFirstName FacLastName
# 0      1111    IS320  SUMMER  ...       MW         None        None
# 1      1234    IS320    FALL  ...       MW      LEONARD       VINCE
# 2      2222    IS460  SUMMER  ...      TTH         None        None
# 3      3333    IS320  SPRING  ...       MW      LEONARD       VINCE
# 4      4321    IS320    FALL  ...      TTH      LEONARD       VINCE
# 5      4444    IS320  WINTER  ...      TTH     VICTORIA    EMMANUEL
# 6      5555   FIN300  WINTER  ...       MW        NICKI       MACON
# 7      5678    IS480  WINTER  ...       MW        JULIA       MILLS
# 8      5679    IS480  SPRING  ...      TTH   CRISTOPHER       COLAN
# 9      6666   FIN450  WINTER  ...      TTH        JULIA       MILLS
# 10     7777   FIN480  SPRING  ...       MW        NICKI       MACON
# 11     8888    IS320  SUMMER  ...       MW      LEONARD       FIBON
# 12     9876    IS460  SPRING  ...      TTH      LEONARD       FIBON
#
# ...

# %%
#If we use inner join or our regular method' we get the following result. Notice that
#2 less records are reported in the query.
txt='''

'''
Q17 =  psql.sqldf(txt)
Q17
# Out:
#     OfferNo CourseNo OffTerm  ...  OffDays FacFirstName FacLastName
# 0      1234    IS320    FALL  ...       MW      LEONARD       VINCE
# 1      3333    IS320  SPRING  ...       MW      LEONARD       VINCE
# 2      4321    IS320    FALL  ...      TTH      LEONARD       VINCE
# 3      4444    IS320  WINTER  ...      TTH     VICTORIA    EMMANUEL
# 4      5555   FIN300  WINTER  ...       MW        NICKI       MACON
# 5      5678    IS480  WINTER  ...       MW        JULIA       MILLS
# 6      5679    IS480  SPRING  ...      TTH   CRISTOPHER       COLAN
# 7      6666   FIN450  WINTER  ...      TTH        JULIA       MILLS
# 8      7777   FIN480  SPRING  ...       MW        NICKI       MACON
# 9      8888    IS320  SUMMER  ...       MW      LEONARD       FIBON
# 10     9876    IS460  SPRING  ...      TTH      LEONARD       FIBON
#
# [11 rows x 10 columns]

# %%
#Q18-List all courses who are not offered 
#Hint Use left Join and look for one of column in Course Table whose value is null.

txt='''
Select *
From Course left join Offering on Course.CourseNo=Offering.CourseNo
Where Offering.CourseNo is null
'''
Q18 =  psql.sqldf(txt)
Q18
# Out:
#   CourseNo                       CrsDesc  CrsUnits OfferNo CourseNo OffTerm  \
# 0    IS470  BUSINESS DATA COMMUNICATIONS         4    None     None    None
#
#   OffYear OffLocation OffTime FacNo OffDays
# 0    None        None    None  None    None

# %% [markdown]
# SUBQUERY

# %%
#Query19-Find StdNo,StdFirstName,StdLastName of Student with 
#StdGPA greater than student with StdNo '123-45-6789'
#I-Find the GPA of student having StdNo  '123-45-6789'
#II-Find StdNo,StdFirstName,StdLastName of Student'StdGPA greater than GPA found in part I.
#Combine I and II


txt='''

'''
Q19I =  psql.sqldf(txt)
Q19I
# Out:
#    StdGPA
# 0     3.0

# %%
#II-Find StdNo,StdFirstName,StdLastName of Student with StdGPA greater than 3.0
txt='''

'''
Q19II =  psql.sqldf(txt)
Q19II
# Out:
#          StdNo StdFirstName StdLastName
# 0  234-56-7890        CANDY     KENDALL
# 1  456-78-9012          JOE     ESTRADA
# 2  567-89-0123       MARIAH       DODGE
# 3  678-90-1234         TESS       DODGE
# 4  876-54-3210   CRISTOPHER       COLAN
# 5  901-23-4567      WILLIAM     PILGRIM

# %%
#Step 2 is not enough as StdGPA of student can change over time
#So we have to make it more general. In order to do that we will 
#Combine II and I
txt='''

'''
Q19 =  psql.sqldf(txt)
Q19
# Out:
#          StdNo StdFirstName StdLastName
# 0  234-56-7890        CANDY     KENDALL
# 1  456-78-9012          JOE     ESTRADA
# 2  567-89-0123       MARIAH       DODGE
# 3  678-90-1234         TESS       DODGE
# 4  876-54-3210   CRISTOPHER       COLAN
# 5  901-23-4567      WILLIAM     PILGRIM

# %%
#Query20-List Faculty Name and Lastname with a Salary higher than 'NICKI MACON'
#I-Write query for Salary of 'NICKI MACON'
#II-Write QUery for FacLastName and FirstName with a Higher salary than salary found in part I
#Combine I and II
txt='''

'''
Q20I =  psql.sqldf(txt)
Q20I
# Out:
#    FacSalary
# 0      65000

# %%
#II-Write QUery for FacLastName and FirstName with a Higher salary than 65000

txt='''

'''
Q20II =  psql.sqldf(txt)
Q20II
# Out:
#   FacFirstName FacLastName
# 0     VICTORIA    EMMANUEL
# 1      LEONARD       FIBON
# 2        JULIA       MILLS

# %%
#Combine II and I as Salary of 'NICKI MACON' can change
txt='''

'''
Q20 =  psql.sqldf(txt)
Q20
# Out:
#   FacFirstName FacLastName
# 0     VICTORIA    EMMANUEL
# 1      LEONARD       FIBON
# 2        JULIA       MILLS

# %%
#List Name of The Faculty who earned less than average salaray of the faculty
#I-Calculate average salary
#-List name of The Faculty who earned less than average salary calculated in I
txt='''

'''
Q21I =  psql.sqldf(txt)
Q21I
# Out:
#    AVG(FacSalary)
# 0         67500.0

# %%
txt='''

'''
Q21II =  psql.sqldf(txt)
Q21II
# Out:
#   FacFirstName FacLastName
# 0      LEONARD       VINCE
# 1        NICKI       MACON
# 2   CRISTOPHER       COLAN

# %%
# List faculty name and lastname who are NOT teaching WINTER 2017
#I-Find FacNo from offering Table who are Offering Course
#II-Get that name if FacNo is NOT in that list
txt='''

'''
Q22I =  psql.sqldf(txt)
Q22I
# Out:
#          FacNo
# 0  543-21-0987
# 1  765-43-2109
# 2  987-65-4321
# 3  987-65-4321

# %%
txt='''

'''
Q22II =  psql.sqldf(txt)
Q22II

# %%
#Q18-List all courses who are not offered. Use nested queries
#Hint First list course offered .

txt='''

'''
Q18 =  psql.sqldf(txt)
Q18
# Out:
#                         CrsDesc
# 0  BUSINESS DATA COMMUNICATIONS

# %% [markdown]
# # Using Query As Table

# %%
#List Faculty Name, Last Name, Faculty Supervisor   and Faculty Hire Date
#Note: Faculty Supervisor   and Faculty Hire Date are stored in Faculty_1 Table
txt='''

'''
Q23 =  psql.sqldf(txt)
Q23
# Out:
#          FacNo FacFirstName  ...                 FacHireDate  FacZipCode
# 0  098-76-5432      LEONARD  ...  2004-04-10 00:00:00.000000  98111-9921
# 1  543-21-0987     VICTORIA  ...  2005-04-15 00:00:00.000000  98011-2242
# 2  654-32-1098      LEONARD  ...  2003-05-01 00:00:00.000000  98121-0094
# 3  765-43-2109        NICKI  ...  2006-04-11 00:00:00.000000  98015-9945
# 4  876-54-3210   CRISTOPHER  ...  2008-03-01 00:00:00.000000  98114-1332
# 5  987-65-4321        JULIA  ...  2009-03-15 00:00:00.000000  98114-9954
#
# [6 rows x 6 columns]

# %%
#Add Faculty Supervisor's Name and Lastnmae to the Table Above
#Hint: Use the result of above Query as Table (Query AS QR) and 
#Link with Faculty Table(Link FacSupervisor with FacNo using left join and above Query for first table)
#In summary, if you replace QUERY with the SQL from above query, you will get the answer.
#SELECT QR.*,Faculty.FacFirstName AS FacSupervisorFirstName,Faculty.FacLastName AS FacSupervisorLastName
#FROM QUERY AS QR LEFT JOIN Faculty on QR.FacSuperVisor=Faculty.FacNo
txt='''

'''
Q24=  psql.sqldf(txt)
Q24
# Out:
#          FacNo FacFirstName  ... FacSupervisorFirstName FacSupervisorLastName
# 0  098-76-5432      LEONARD  ...                LEONARD                 FIBON
# 1  543-21-0987     VICTORIA  ...                   None                  None
# 2  654-32-1098      LEONARD  ...               VICTORIA              EMMANUEL
# 3  765-43-2109        NICKI  ...                   None                  None
# 4  876-54-3210   CRISTOPHER  ...                LEONARD                 FIBON
# 5  987-65-4321        JULIA  ...                  NICKI                 MACON
#
# [6 rows x 8 columns]

# %% [markdown]
# #Common Table Expressions (CTE)
#
# The Common Table Expressions (CTE) were introduced into standard SQL in order to simplify various classes of SQL Queries for which a derived table was just unsuitable. CTE was introduced in SQL Server 2005, the common table expression (CTE) is a temporary named result set that you can reference within a SELECT, INSERT, UPDATE, or DELETE statement.
#
#
# After you define your WITH clause with the CTEs, you can then reference the CTEs as you would refer any other table. However, you can refer a CTE only within the execution scope of the statement that immediately follows the WITH clause. After you’ve run your statement, the CTE result set is not available to other statements.
#
# Taken from https://www.geeksforgeeks.org/cte-in-sql/?ref=lbp

# %%
txt='''
WITH FacTable(Faculty.FacNo) AS (
SELECT Faculty.FacNo,	FacFirstName,	FacLastName,	FacSupervisor,FacHireDate	,FacZipCode
FROM Faculty, Faculty_1
WHERE Faculty.FacNo=Faculty_1.FacNo    
)

SELECT FacTable.*,Faculty.FacFirstName AS FacSupervisorFirstName,Faculty.FacLastName AS FacSupervisorLastName
FROM FacTable LEFT JOIN Faculty on FacTable.FacSuperVisor=Faculty.FacNo


'''
Q24=  psql.sqldf(txt)
Q24
# Out:
#          FacNo FacFirstName FacLastName FacSupervisor  \
# 0  098-76-5432      LEONARD       VINCE   654-32-1098
# 1  543-21-0987     VICTORIA    EMMANUEL          None
# 2  654-32-1098      LEONARD       FIBON   543-21-0987
# 3  765-43-2109        NICKI       MACON          None
# 4  876-54-3210   CRISTOPHER       COLAN   654-32-1098
# 5  987-65-4321        JULIA       MILLS   765-43-2109
#
#                   FacHireDate  FacZipCode FacSupervisorFirstName  \
# 0  2004-04-10 00:00:00.000000  98111-9921                LEONARD
# 1  2005-04-15 00:00:00.000000  98011-2242                   None
# 2  2003-05-01 00:00:00.000000  98121-0094               VICTORIA
# 3  2006-04-11 00:00:00.000000  98015-9945                   None
# 4  2008-03-01 00:00:00.000000  98114-1332                LEONARD
# 5  2009-03-15 00:00:00.000000  98114-9954                  NICKI
#
#   FacSupervisorLastName
# 0                 FIBON
# 1                  None
# 2              EMMANUEL
# ...

# %%
txt='''
WITH FacTable2(FacultyNo,FacultyFirstName,	FacultyLastName) AS (
SELECT Faculty.FacNo,FacFirstName,	FacLastName
FROM Faculty, Faculty_1
WHERE Faculty.FacNo=Faculty_1.FacNo    
)


SELECT *
FROM FacTable2


'''
Q25=  psql.sqldf(txt)
Q25
# Out:
#      FacultyNo FacultyFirstName FacultyLastName
# 0  098-76-5432          LEONARD           VINCE
# 1  543-21-0987         VICTORIA        EMMANUEL
# 2  654-32-1098          LEONARD           FIBON
# 3  765-43-2109            NICKI           MACON
# 4  876-54-3210       CRISTOPHER           COLAN
# 5  987-65-4321            JULIA           MILLS
